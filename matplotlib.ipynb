# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.arange(-20, 20)
f = np.sin(x)/x
plt.plot(x, f, label = u'sin(x)/x', color = 'r') 
plt.grid(True)
plt.xlabel(u'x')
plt.ylabel(u'y')
plt.legend(frameon = False)
# Out:
# /home/nbuser/anaconda3_501/lib/python3.6/site-packages/ipykernel/__main__.py:4: RuntimeWarning: invalid value encountered in true_divide
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-06b374210328> in <module>
#       5 plt.plot(x, f, label = u'sin(x)/x', color = 'r')
#       6 plt.grid(True)
# ----> 7 plt.xlabel(u'x')
#       8 plt.ylabel(u'y')
#       9 plt.legend(frameon = False)
#
# TypeError: 'str' object is not callable
